# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Load dataset
titanic = pd.read_csv('train.csv')

# Fill missing values
titanic['Age'].fillna(titanic.groupby(['Pclass', 'Sex'])['Age'].transform('median'), inplace=True)
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# Feature engineering
titanic['FamilySize'] = titanic['SibSp'] + titanic['Parch'] + 1
titanic['IsAlone'] = (titanic['FamilySize'] == 1).astype(int)

# Extract titles from names
titanic['Title'] = titanic['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# Encode categorical variables
titanic = pd.get_dummies(titanic, columns=['Sex', 'Embarked', 'Pclass', 'Title'], drop_first=True)

# Scale numerical features
scaler = StandardScaler()
titanic['Fare'] = scaler.fit_transform(titanic[['Fare']])
titanic['Age'] = scaler.fit_transform(titanic[['Age']])

# Drop irrelevant features
titanic.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# Separate features and target variable
X = titanic.drop('Survived', axis=1)
y = titanic['Survived']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Combine features and target into single dataframes
train_data = X_train.copy()
train_data['Survived'] = y_train

test_data = X_test.copy()
test_data['Survived'] = y_test

# Function to safely access columns
def safe_get(row, column, default=0):
    return row[column] if column in row else default

# Create descriptive sentences for training set
def create_train_sentence(row):
    sentence = f"A {'male' if safe_get(row, 'Sex_male') == 1 else 'female'} passenger, aged {row['Age']:.2f}, "
    sentence += f"of {'higher' if safe_get(row, 'Pclass_2') == 1 else 'middle' if safe_get(row, 'Pclass_3') == 1 else 'lower'} class, "
    sentence += f"with a fare of {row['Fare']:.2f}. "
    sentence += f"Embarked from {'Cherbourg' if safe_get(row, 'Embarked_C') == 1 else 'Queenstown' if safe_get(row, 'Embarked_Q') == 1 else 'Southampton'}. "
    sentence += f"Has a family size of {row['FamilySize']} and {'is alone' if row['IsAlone'] == 1 else 'is not alone'}. "
    titles = ['Mr', 'Miss', 'Mrs', 'Master', 'Other']
    for title in titles:
        if f'Title_{title}' in row and row[f'Title_{title}'] == 1:
            sentence += f"Holds the title of {title}. "
            break
    sentence += f"Survived: {'yes' if row['Survived'] == 1 else 'no'}."
    return sentence

# Create descriptive sentences for test set
def create_test_sentence(row):
    sentence = f"A {'male' if safe_get(row, 'Sex_male') == 1 else 'female'} passenger, aged {row['Age']:.2f}, "
    sentence += f"of {'higher' if safe_get(row, 'Pclass_2') == 1 else 'middle' if safe_get(row, 'Pclass_3') == 1 else 'lower'} class, "
    sentence += f"with a fare of {row['Fare']:.2f}. "
    sentence += f"Embarked from {'Cherbourg' if safe_get(row, 'Embarked_C') == 1 else 'Queenstown' if safe_get(row, 'Embarked_Q') == 1 else 'Southampton'}. "
    sentence += f"Has a family size of {row['FamilySize']} and {'is alone' if row['IsAlone'] == 1 else 'is not alone'}. "
    titles = ['Mr', 'Miss', 'Mrs', 'Master', 'Other']
    for title in titles:
        if f'Title_{title}' in row and row[f'Title_{title}'] == 1:
            sentence += f"Holds the title of {title}. "
            break
    sentence += "Will this passenger survive?"
    return sentence

# Apply to all rows
train_sentences = train_data.apply(create_train_sentence, axis=1)
test_sentences = test_data.apply(create_test_sentence, axis=1)

# Display a few examples
print("Training Examples:")
for i in range(5):
    print(train_sentences.iloc[i])

print("\nTest Examples:")
for i in range(5):
    print(test_sentences.iloc[i])
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\.'
# <>:17: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\yukte\AppData\Local\Temp\ipykernel_13120\3463407682.py:17: SyntaxWarning: invalid escape sequence '\.'
#   titanic['Title'] = titanic['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# Training Examples:
# A male passenger, aged -1.89, of lower class, with a fare of 1.00. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
# A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
# A female passenger, aged -2.11, of middle class, with a fare of -0.42. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
# A male passenger, aged 0.52, of higher class, with a fare of -0.09. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mr. Survived: no.
# A male passenger, aged 1.04, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# Test Examples:
# A male passenger, aged -0.31, of middle class, with a fare of -0.34. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Will this passenger survive?
# A male passenger, aged 0.14, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Will this passenger survive?
# A male passenger, aged -0.69, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Will this passenger survive?
# A female passenger, aged -1.74, of higher class, with a fare of 0.02. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Will this passenger survive?
# A female passenger, aged -1.14, of middle class, with a fare of -0.42. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Will this passenger survive?
# C:\Users\yukte\AppData\Local\Temp\ipykernel_13120\3463407682.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Age'].fillna(titanic.groupby(['Pclass', 'Sex'])['Age'].transform('median'), inplace=True)
# C:\Users\yukte\AppData\Local\Temp\ipykernel_13120\3463407682.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# %%
# Create dictionaries for training and test sentences
train_dict = {i: sentence for i, sentence in enumerate(train_sentences)}
test_dict = {i: sentence for i, sentence in enumerate(test_sentences)}

# Display a few examples
print("Training Dictionary Examples:")
for i in range(5):
    print(f"{i}: {train_dict[i]}")

print("\nTest Dictionary Examples:")
for i in range(5):
    print(f"{i}: {test_dict[i]}")
# Out:
# Training Dictionary Examples:
# 0: A male passenger, aged -1.89, of lower class, with a fare of 1.00. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
# 1: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
# 2: A female passenger, aged -2.11, of middle class, with a fare of -0.42. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
# 3: A male passenger, aged 0.52, of higher class, with a fare of -0.09. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mr. Survived: no.
# 4: A male passenger, aged 1.04, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# Test Dictionary Examples:
# 0: A male passenger, aged -0.31, of middle class, with a fare of -0.34. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Will this passenger survive?
# 1: A male passenger, aged 0.14, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Will this passenger survive?
# 2: A male passenger, aged -0.69, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Will this passenger survive?
# 3: A female passenger, aged -1.74, of higher class, with a fare of 0.02. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Will this passenger survive?
# 4: A female passenger, aged -1.14, of middle class, with a fare of -0.42. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Will this passenger survive?

# %%
# Concatenate all test sentences into a single prompt
prompt = "\n\n"
for key, sentence in train_dict.items():
    prompt += f"{key}: {sentence}\n\n"

# %%
# Concatenate all test sentences into a single prompt
prompt2 = "\n\n"
for key, sentence in test_dict.items():
    prompt2 += f"{key}: {sentence}\n\n"

# %%
print(prompt)
# Out:
# 0: A male passenger, aged 1.23, of lower class, with a fare of -0.07. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 1: A male passenger, aged -0.46, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 2: A male passenger, aged 0.22, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 3: A male passenger, aged -0.23, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 4: A female passenger, aged -1.74, of middle class, with a fare of -0.02. Embarked from Southampton. Has a family size of 7 and is not alone. Holds the title of Miss. Survived: no.
#
# 5: A male passenger, aged -0.38, of lower class, with a fare of 4.34. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 6: A male passenger, aged 1.19, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Survived: no.
#
# 7: A male passenger, aged -0.01, of higher class, with a fare of -0.09. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 8: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 9: A male passenger, aged 0.82, of lower class, with a fare of 0.07. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 10: A female passenger, aged 0.97, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 11: A male passenger, aged 0.52, of middle class, with a fare of -0.16. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 12: A male passenger, aged 0.29, of higher class, with a fare of -0.40. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 13: A male passenger, aged -0.91, of middle class, with a fare of -0.51. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 14: A male passenger, aged -0.01, of middle class, with a fare of -0.46. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 15: A female passenger, aged 1.57, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 16: A female passenger, aged 0.44, of lower class, with a fare of 1.16. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 17: A female passenger, aged 0.67, of lower class, with a fare of 3.93. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 18: A male passenger, aged 0.37, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 19: A female passenger, aged -0.91, of lower class, with a fare of 0.50. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 20: A female passenger, aged -1.36, of middle class, with a fare of -0.02. Embarked from Southampton. Has a family size of 7 and is not alone. Holds the title of Miss. Survived: no.
#
# 21: A male passenger, aged 2.40, of middle class, with a fare of -0.52. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 22: A female passenger, aged 0.07, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 23: A female passenger, aged -1.66, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 24: A female passenger, aged 2.55, of middle class, with a fare of -0.46. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 25: A male passenger, aged -0.69, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 26: A female passenger, aged -0.57, of middle class, with a fare of -0.20. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 27: A male passenger, aged -0.01, of middle class, with a fare of -0.46. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 28: A male passenger, aged 0.52, of lower class, with a fare of 1.77. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mr. Survived: yes.
#
# 29: A male passenger, aged -0.31, of middle class, with a fare of -0.36. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 30: A male passenger, aged 1.57, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 31: A male passenger, aged -0.16, of lower class, with a fare of 3.61. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 32: A male passenger, aged 0.07, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 33: A female passenger, aged 0.29, of lower class, with a fare of 1.16. Embarked from Queenstown. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: yes.
#
# 34: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 35: A female passenger, aged -0.57, of middle class, with a fare of -0.14. Embarked from Southampton. Has a family size of 5 and is not alone. Holds the title of Miss. Survived: no.
#
# 36: A male passenger, aged -2.04, of middle class, with a fare of -0.22. Embarked from Southampton. Has a family size of 5 and is not alone. Holds the title of Master. Survived: no.
#
# 37: A female passenger, aged -0.31, of higher class, with a fare of -0.04. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 38: A male passenger, aged 1.65, of lower class, with a fare of 0.59. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 39: A female passenger, aged -0.31, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 40: A male passenger, aged -0.31, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 41: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 42: A female passenger, aged -0.38, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 43: A male passenger, aged -0.84, of middle class, with a fare of -0.24. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 44: A male passenger, aged 0.82, of lower class, with a fare of -0.03. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 45: A male passenger, aged -0.31, of middle class, with a fare of -0.51. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 46: A female passenger, aged -0.38, of higher class, with a fare of -0.36. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 47: A male passenger, aged -0.53, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 48: A male passenger, aged -2.12, of lower class, with a fare of 2.40. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Master. Survived: yes.
#
# 49: A female passenger, aged -0.38, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 50: A female passenger, aged -0.23, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 51: A male passenger, aged 0.37, of higher class, with a fare of -0.23. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 52: A female passenger, aged -0.61, of lower class, with a fare of 4.63. Embarked from Southampton. Has a family size of 5 and is not alone. Holds the title of Miss. Survived: yes.
#
# 53: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 54: A female passenger, aged -0.57, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 55: A male passenger, aged -0.31, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 56: A female passenger, aged -0.53, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 57: A female passenger, aged 2.47, of lower class, with a fare of 0.96. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 58: A female passenger, aged -0.84, of middle class, with a fare of -0.45. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 59: A female passenger, aged 0.97, of lower class, with a fare of 3.93. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 60: A male passenger, aged 2.10, of higher class, with a fare of -0.40. Embarked from Queenstown. Has a family size of 1 and is alone. Survived: no.
#
# 61: A male passenger, aged -0.76, of middle class, with a fare of -0.65. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 62: A female passenger, aged 0.97, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 63: A male passenger, aged -0.31, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 64: A female passenger, aged -0.69, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 65: A male passenger, aged 0.41, of middle class, with a fare of -0.52. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 66: A male passenger, aged -0.08, of middle class, with a fare of -0.46. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 67: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 68: A male passenger, aged -0.46, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 69: A male passenger, aged -0.53, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 70: A male passenger, aged 1.72, of lower class, with a fare of -0.03. Embarked from Southampton. Has a family size of 1 and is alone. Survived: yes.
#
# 71: A female passenger, aged 0.07, of middle class, with a fare of -0.40. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 72: A male passenger, aged 0.56, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 73: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 74: A male passenger, aged -0.53, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 75: A male passenger, aged 1.57, of lower class, with a fare of 2.04. Embarked from Southampton. Has a family size of 3 and is not alone. Survived: yes.
#
# 76: A male passenger, aged -0.16, of middle class, with a fare of -0.51. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 77: A male passenger, aged -0.53, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 78: A female passenger, aged 1.65, of lower class, with a fare of 0.92. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 79: A male passenger, aged 0.52, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 80: A female passenger, aged -0.01, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 81: A female passenger, aged -0.53, of lower class, with a fare of 2.40. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 82: A male passenger, aged 1.57, of lower class, with a fare of 1.49. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 83: A female passenger, aged 0.82, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 84: A male passenger, aged -0.16, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 85: A male passenger, aged 0.82, of lower class, with a fare of -0.65. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 86: A male passenger, aged 2.70, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 87: A male passenger, aged -0.91, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 88: A male passenger, aged -0.08, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 89: A male passenger, aged -1.89, of lower class, with a fare of 1.00. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
#
# 90: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 91: A female passenger, aged -2.11, of middle class, with a fare of -0.42. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 92: A male passenger, aged 0.52, of higher class, with a fare of -0.09. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mr. Survived: no.
#
# 93: A male passenger, aged 1.04, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 94: A male passenger, aged 0.67, of lower class, with a fare of 2.44. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 95: A female passenger, aged 0.14, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 96: A male passenger, aged -0.01, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 97: A male passenger, aged -0.84, of middle class, with a fare of -0.48. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 98: A male passenger, aged 0.07, of higher class, with a fare of -0.35. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 99: A female passenger, aged 0.74, of lower class, with a fare of 1.58. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 100: A male passenger, aged 0.74, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 101: A male passenger, aged -0.23, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 102: A male passenger, aged -0.69, of middle class, with a fare of -0.51. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 103: A female passenger, aged 0.44, of lower class, with a fare of 2.04. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 104: A male passenger, aged 1.50, of middle class, with a fare of -0.65. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 105: A male passenger, aged -0.46, of higher class, with a fare of -0.35. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 106: A male passenger, aged -2.11, of middle class, with a fare of 0.15. Embarked from Southampton. Has a family size of 6 and is not alone. Holds the title of Master. Survived: no.
#
# 107: A female passenger, aged -0.57, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 108: A male passenger, aged -0.31, of middle class, with a fare of -0.18. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mr. Survived: no.
#
# 109: A male passenger, aged -1.96, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
#
# 110: A male passenger, aged -1.89, of middle class, with a fare of -0.42. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
#
# 111: A male passenger, aged -0.76, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 112: A male passenger, aged 0.86, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 113: A female passenger, aged -2.11, of middle class, with a fare of -0.33. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 114: A female passenger, aged -0.57, of middle class, with a fare of -0.34. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: no.
#
# 115: A male passenger, aged -0.61, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 116: A male passenger, aged 1.87, of lower class, with a fare of 0.40. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 117: A male passenger, aged -0.31, of middle class, with a fare of -0.34. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 118: A male passenger, aged -0.31, of higher class, with a fare of 0.19. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mr. Survived: no.
#
# 119: A male passenger, aged -0.23, of middle class, with a fare of -0.36. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 120: A female passenger, aged -0.53, of middle class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 121: A female passenger, aged 0.14, of middle class, with a fare of -0.24. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 122: A male passenger, aged 1.50, of lower class, with a fare of 1.15. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: yes.
#
# 123: A male passenger, aged -0.76, of higher class, with a fare of 0.09. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 124: A male passenger, aged -0.38, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 125: A male passenger, aged -0.99, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 126: A male passenger, aged -0.31, of lower class, with a fare of 0.47. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: yes.
#
# 127: A male passenger, aged 0.74, of middle class, with a fare of -0.16. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 128: A female passenger, aged 1.35, of middle class, with a fare of -0.36. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: no.
#
# 129: A male passenger, aged 2.32, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Survived: no.
#
# 130: A male passenger, aged -0.38, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 131: A male passenger, aged 0.82, of lower class, with a fare of 0.36. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 132: A female passenger, aged -0.16, of higher class, with a fare of -0.23. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: no.
#
# 133: A male passenger, aged 0.07, of higher class, with a fare of -0.37. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 134: A male passenger, aged 0.67, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 135: A male passenger, aged 1.12, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 136: A female passenger, aged -0.61, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 137: A female passenger, aged -0.38, of middle class, with a fare of -0.31. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 138: A female passenger, aged 1.19, of higher class, with a fare of -0.38. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 139: A male passenger, aged -1.59, of higher class, with a fare of 0.09. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
#
# 140: A female passenger, aged -1.59, of middle class, with a fare of -0.22. Embarked from Southampton. Has a family size of 5 and is not alone. Holds the title of Miss. Survived: no.
#
# 141: A male passenger, aged 0.82, of lower class, with a fare of 0.06. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 142: A male passenger, aged 0.22, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 143: A male passenger, aged 1.57, of lower class, with a fare of 0.48. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 144: A male passenger, aged -0.61, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 145: A female passenger, aged 1.57, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 146: A female passenger, aged -0.46, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 147: A male passenger, aged 0.22, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 148: A female passenger, aged -0.57, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 149: A female passenger, aged -0.61, of middle class, with a fare of 0.04. Embarked from Southampton. Has a family size of 5 and is not alone. Holds the title of Miss. Survived: no.
#
# 150: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 151: A male passenger, aged -0.31, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 152: A male passenger, aged -1.06, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 153: A female passenger, aged 0.14, of middle class, with a fare of -0.29. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: no.
#
# 154: A male passenger, aged -0.31, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 155: A male passenger, aged 1.87, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 156: A male passenger, aged -0.08, of lower class, with a fare of 0.30. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 157: A female passenger, aged 0.67, of lower class, with a fare of 0.96. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 158: A female passenger, aged 0.89, of higher class, with a fare of -0.26. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 159: A male passenger, aged 0.29, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 160: A male passenger, aged 1.72, of higher class, with a fare of -0.38. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 161: A male passenger, aged -0.99, of middle class, with a fare of -0.24. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 162: A male passenger, aged -0.69, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 163: A male passenger, aged -1.51, of middle class, with a fare of -0.02. Embarked from Southampton. Has a family size of 7 and is not alone. Holds the title of Master. Survived: no.
#
# 164: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 165: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 166: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 167: A female passenger, aged 1.87, of lower class, with a fare of 0.55. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 168: A male passenger, aged -0.23, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 169: A male passenger, aged 2.32, of lower class, with a fare of 0.95. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: yes.
#
# 170: A male passenger, aged -0.31, of middle class, with a fare of 0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 171: A female passenger, aged 1.12, of lower class, with a fare of 0.52. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 172: A male passenger, aged -0.69, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: yes.
#
# 173: A male passenger, aged -0.31, of middle class, with a fare of -0.14. Embarked from Southampton. Has a family size of 5 and is not alone. Holds the title of Master. Survived: no.
#
# 174: A male passenger, aged -0.99, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 175: A female passenger, aged 1.04, of middle class, with a fare of 0.30. Embarked from Southampton. Has a family size of 8 and is not alone. Holds the title of Mrs. Survived: no.
#
# 176: A male passenger, aged -0.91, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 177: A male passenger, aged 0.59, of lower class, with a fare of 0.41. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: yes.
#
# 178: A male passenger, aged 2.47, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 179: A male passenger, aged -1.59, of middle class, with a fare of -0.06. Embarked from Queenstown. Has a family size of 6 and is not alone. Holds the title of Master. Survived: no.
#
# 180: A male passenger, aged 0.22, of middle class, with a fare of 0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 181: A female passenger, aged -0.69, of middle class, with a fare of -0.45. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: no.
#
# 182: A female passenger, aged -0.08, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 183: A female passenger, aged -0.61, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 184: A male passenger, aged 0.59, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 185: A female passenger, aged -0.91, of middle class, with a fare of -0.36. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 186: A female passenger, aged -0.57, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 187: A male passenger, aged 1.27, of lower class, with a fare of 0.58. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 188: A male passenger, aged -0.31, of middle class, with a fare of -0.34. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 189: A male passenger, aged -0.38, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 190: A male passenger, aged -0.01, of lower class, with a fare of 0.69. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 191: A female passenger, aged 2.02, of lower class, with a fare of 1.03. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 192: A male passenger, aged 0.14, of higher class, with a fare of 0.10. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 193: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 194: A male passenger, aged 0.22, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: yes.
#
# 195: A male passenger, aged 0.29, of middle class, with a fare of -0.24. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 196: A male passenger, aged 2.25, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 197: A female passenger, aged 2.17, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 198: A female passenger, aged -0.57, of middle class, with a fare of -0.32. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 199: A female passenger, aged -1.96, of higher class, with a fare of 0.19. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Miss. Survived: yes.
#
# 200: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 201: A female passenger, aged -0.99, of lower class, with a fare of 0.52. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: yes.
#
# 202: A female passenger, aged 1.19, of middle class, with a fare of -0.09. Embarked from Southampton. Has a family size of 6 and is not alone. Holds the title of Mrs. Survived: no.
#
# 203: A female passenger, aged 1.04, of lower class, with a fare of 3.61. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 204: A female passenger, aged 0.07, of lower class, with a fare of 1.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 205: A male passenger, aged -0.05, of middle class, with a fare of -0.32. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 206: A male passenger, aged -0.38, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 207: A male passenger, aged 0.07, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 208: A male passenger, aged 0.52, of lower class, with a fare of 0.16. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 209: A male passenger, aged -0.31, of middle class, with a fare of -0.51. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 210: A female passenger, aged -0.57, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: no.
#
# 211: A female passenger, aged 1.57, of lower class, with a fare of -0.07. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 212: A female passenger, aged -2.13, of middle class, with a fare of -0.26. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Miss. Survived: yes.
#
# 213: A female passenger, aged -0.38, of lower class, with a fare of 0.35. Embarked from Southampton. Has a family size of 1 and is alone. Survived: yes.
#
# 214: A female passenger, aged -0.38, of higher class, with a fare of 0.66. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Miss. Survived: yes.
#
# 215: A female passenger, aged 0.44, of lower class, with a fare of 0.40. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 216: A female passenger, aged 0.07, of lower class, with a fare of 1.09. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 217: A male passenger, aged -0.46, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 218: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 219: A male passenger, aged -0.16, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 220: A female passenger, aged 1.95, of higher class, with a fare of -0.33. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 221: A female passenger, aged 0.44, of lower class, with a fare of 0.42. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 222: A male passenger, aged -0.31, of middle class, with a fare of -0.51. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 223: A female passenger, aged 0.44, of lower class, with a fare of 0.95. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 224: A male passenger, aged -0.31, of middle class, with a fare of -0.25. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 225: A female passenger, aged -0.46, of higher class, with a fare of -0.37. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 226: A female passenger, aged -0.57, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 227: A female passenger, aged -0.46, of lower class, with a fare of 1.63. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: yes.
#
# 228: A male passenger, aged 1.65, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 229: A female passenger, aged 0.29, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 230: A female passenger, aged -0.01, of middle class, with a fare of -0.22. Embarked from Southampton. Has a family size of 5 and is not alone. Holds the title of Mrs. Survived: no.
#
# 231: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 232: A male passenger, aged -0.31, of middle class, with a fare of 0.75. Embarked from Southampton. Has a family size of 11 and is not alone. Holds the title of Mr. Survived: no.
#
# 233: A female passenger, aged -2.04, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 234: A female passenger, aged -1.14, of higher class, with a fare of -0.04. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 235: A male passenger, aged 1.87, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Survived: no.
#
# 236: A female passenger, aged -1.06, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 237: A female passenger, aged -0.53, of lower class, with a fare of 0.46. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: yes.
#
# 238: A male passenger, aged -0.16, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 239: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 240: A male passenger, aged 0.82, of lower class, with a fare of 0.15. Embarked from Southampton. Has a family size of 1 and is alone. Survived: no.
#
# 241: A female passenger, aged -0.08, of higher class, with a fare of -0.17. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 242: A male passenger, aged 0.74, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 243: A male passenger, aged -2.04, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
#
# 244: A male passenger, aged -0.38, of middle class, with a fare of -0.32. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 245: A male passenger, aged 0.22, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 246: A male passenger, aged 1.23, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 247: A female passenger, aged -1.59, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 248: A male passenger, aged -0.23, of middle class, with a fare of -0.23. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mr. Survived: no.
#
# 249: A female passenger, aged -0.01, of lower class, with a fare of 3.61. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 250: A female passenger, aged 1.19, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 251: A female passenger, aged 0.52, of middle class, with a fare of -0.30. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 252: A male passenger, aged 0.82, of lower class, with a fare of -0.12. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 253: A female passenger, aged -1.89, of middle class, with a fare of -0.20. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 254: A male passenger, aged -0.99, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 255: A male passenger, aged 2.17, of lower class, with a fare of -0.05. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 256: A male passenger, aged 0.86, of middle class, with a fare of -0.36. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 257: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 258: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 259: A male passenger, aged 1.65, of middle class, with a fare of -0.51. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 260: A male passenger, aged 0.07, of higher class, with a fare of -0.65. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 261: A female passenger, aged -0.91, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 7 and is not alone. Holds the title of Miss. Survived: yes.
#
# 262: A male passenger, aged -0.31, of middle class, with a fare of -0.51. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 263: A male passenger, aged 0.82, of middle class, with a fare of -0.34. Embarked from Queenstown. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 264: A male passenger, aged -0.31, of middle class, with a fare of -0.65. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 265: A male passenger, aged 1.35, of lower class, with a fare of -0.13. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 266: A male passenger, aged 0.82, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 267: A male passenger, aged 1.12, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 268: A female passenger, aged -0.46, of lower class, with a fare of 4.65. Embarked from Southampton. Has a family size of 6 and is not alone. Holds the title of Miss. Survived: yes.
#
# 269: A male passenger, aged -0.84, of higher class, with a fare of -0.42. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# ...
#
# 623: A female passenger, aged 0.82, of higher class, with a fare of -0.33. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mrs. Survived: yes.
#
# 624: A male passenger, aged 2.47, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 625: A female passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: no.
#
# 626: A male passenger, aged -0.23, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 627: A female passenger, aged -0.84, of middle class, with a fare of -0.36. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: no.
#
# 628: A male passenger, aged 0.37, of higher class, with a fare of -0.23. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 629: A male passenger, aged 1.42, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 630: A male passenger, aged -0.08, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 631: A male passenger, aged -0.38, of middle class, with a fare of -0.16. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 632: A female passenger, aged -0.91, of higher class, with a fare of -0.41. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 633: A female passenger, aged 0.67, of lower class, with a fare of 0.79. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 634: A male passenger, aged -0.31, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 635: A male passenger, aged 0.82, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 636: A male passenger, aged -0.53, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 637: A female passenger, aged -2.04, of middle class, with a fare of -0.44. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: no.
#
# 638: A male passenger, aged -0.08, of lower class, with a fare of 1.01. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 639: A male passenger, aged -0.84, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 640: A male passenger, aged -0.08, of middle class, with a fare of -0.19. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 641: A female passenger, aged -0.76, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 642: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 643: A female passenger, aged 2.32, of lower class, with a fare of 0.87. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 644: A male passenger, aged -0.69, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 645: A male passenger, aged 1.19, of lower class, with a fare of 0.07. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 646: A female passenger, aged -0.57, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 647: A female passenger, aged -0.38, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 648: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 649: A female passenger, aged -0.57, of middle class, with a fare of -0.34. Embarked from Queenstown. Has a family size of 2 and is not alone. Holds the title of Miss. Survived: yes.
#
# 650: A male passenger, aged 0.74, of middle class, with a fare of -0.02. Embarked from Southampton. Has a family size of 7 and is not alone. Holds the title of Mr. Survived: no.
#
# 651: A female passenger, aged -0.23, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 652: A female passenger, aged -0.38, of higher class, with a fare of -0.10. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 653: A female passenger, aged 0.52, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 654: A male passenger, aged 0.59, of lower class, with a fare of -0.05. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 655: A female passenger, aged 0.44, of lower class, with a fare of 0.46. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 656: A male passenger, aged -0.08, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 657: A male passenger, aged -0.76, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 658: A male passenger, aged 1.04, of middle class, with a fare of -0.52. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 659: A male passenger, aged -0.31, of lower class, with a fare of 1.19. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: yes.
#
# 660: A male passenger, aged 1.35, of middle class, with a fare of -0.47. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 661: A female passenger, aged -0.99, of lower class, with a fare of 1.09. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 662: A male passenger, aged -2.13, of higher class, with a fare of -0.27. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Master. Survived: yes.
#
# 663: A male passenger, aged -0.53, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 664: A male passenger, aged -0.76, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 665: A male passenger, aged -0.08, of higher class, with a fare of -0.38. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 666: A male passenger, aged -1.14, of middle class, with a fare of 0.15. Embarked from Southampton. Has a family size of 6 and is not alone. Holds the title of Mr. Survived: no.
#
# 667: A male passenger, aged 0.52, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 668: A male passenger, aged -0.01, of lower class, with a fare of -0.04. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 669: A male passenger, aged 0.97, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 670: A male passenger, aged 0.82, of lower class, with a fare of 0.40. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 671: A male passenger, aged -0.16, of lower class, with a fare of 0.90. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 672: A male passenger, aged -0.01, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 673: A female passenger, aged -1.81, of higher class, with a fare of -0.09. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Miss. Survived: yes.
#
# 674: A female passenger, aged -0.53, of middle class, with a fare of -0.45. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 675: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 676: A female passenger, aged 0.07, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 677: A male passenger, aged 2.47, of lower class, with a fare of -0.11. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 678: A male passenger, aged 0.37, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: yes.
#
# 679: A male passenger, aged -0.08, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 680: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 681: A male passenger, aged 1.12, of middle class, with a fare of -0.32. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 682: A female passenger, aged 1.19, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: no.
#
# 683: A male passenger, aged -0.76, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 684: A male passenger, aged -0.84, of higher class, with a fare of 0.83. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 685: A male passenger, aged 0.14, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 686: A male passenger, aged 0.07, of higher class, with a fare of -0.65. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 687: A male passenger, aged -0.61, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 688: A male passenger, aged -0.31, of higher class, with a fare of -0.39. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 689: A male passenger, aged 0.22, of middle class, with a fare of -0.48. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 690: A male passenger, aged 0.07, of higher class, with a fare of -0.17. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 691: A male passenger, aged 0.82, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 692: A male passenger, aged 0.29, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 693: A male passenger, aged 0.52, of middle class, with a fare of -0.50. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 694: A female passenger, aged 1.35, of lower class, with a fare of 0.41. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 695: A male passenger, aged 0.37, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 696: A male passenger, aged -0.76, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 697: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 698: A female passenger, aged 1.57, of higher class, with a fare of -0.44. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 699: A female passenger, aged -0.57, of middle class, with a fare of -0.18. Embarked from Queenstown. Has a family size of 3 and is not alone. Holds the title of Miss. Survived: yes.
#
# 700: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Queenstown. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.
#
# 701: A male passenger, aged 0.07, of higher class, with a fare of -0.65. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 702: A male passenger, aged -0.31, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 703: A male passenger, aged 0.44, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 704: A male passenger, aged 0.44, of higher class, with a fare of -0.12. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 705: A female passenger, aged -0.84, of lower class, with a fare of 3.93. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mrs. Survived: yes.
#
# 706: A female passenger, aged -0.99, of middle class, with a fare of 0.30. Embarked from Southampton. Has a family size of 8 and is not alone. Holds the title of Miss. Survived: no.
#
# 707: A female passenger, aged -0.61, of middle class, with a fare of -0.49. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Miss. Survived: yes.
#
# 708: A male passenger, aged 0.82, of lower class, with a fare of -0.02. Embarked from Southampton. Has a family size of 1 and is alone. Holds the title of Mr. Survived: no.
#
# 709: A male passenger, aged 0.89, of middle class, with a fare of -0.36. Embarked from Southampton. Has a family size of 3 and is not alone. Holds the title of Mr. Survived: no.
#
# 710: A female passenger, aged -1.14, of lower class, with a fare of 1.77. Embarked from Southampton. Has a family size of 4 and is not alone. Holds the title of Miss. Survived: yes.
#
# 711: A male passenger, aged -0.61, of lower class, with a fare of 0.91. Embarked from Southampton. Has a family size of 2 and is not alone. Holds the title of Mr. Survived: no.

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

analysis_string = """Generate the analysis based on instruction\ that
is delimited by triple backticks.\instruction: ```{instruction_analyis}```
"""

instruction_analysis = f"""You are functioning as an AI prediction analyst whose job is to learn patterns from the data provided of who survived an accident and who didnt.
1. You are given few examples of which passenger survived and who didnt here {prompt}
2. What are the key differences in terms of different charecteristics whether its ticket price, marital status etc to differentiate who survived and who perished
6. We are trying to frame the analysis in a way so that with this limited data you can make a reasonable guess if passenger survived or perished in the accident 
"""

analysis_template = ChatPromptTemplate.from_template(analysis_string)

chat = ChatOpenAI(temperature=0.0, model="gpt-4-turbo", openai_api_key='')
user_analysis = analysis_template.format_messages(instruction_analyis=instruction_analysis)
response = chat(user_analysis)
text=response.content
print(text)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\yukte\AppData\Local\Temp\ipykernel_18092\3187832319.py:4: SyntaxWarning: invalid escape sequence '\ '
#   analysis_string = """Generate the analysis based on instruction\ that
# ### Analysis of Survival Patterns Based on Passenger Data
#
# #### Overview
# The provided data includes various attributes of passengers such as age, class, fare, embarkation point, family size, whether they were alone, title, and survival status. By analyzing these attributes, we can identify patterns and factors that may have influenced the likelihood of survival.
#
# #### Key Observations and Patterns
#
# 1. **Gender and Title**:
#    - Titles such as "Mrs." and "Miss" (typically female) show a higher survival rate compared to "Mr." (typically male). This suggests that women had a higher likelihood of survival.
#    - Titles like "Master," which usually refer to young males, also show a relatively higher survival rate, indicating that children were more likely to survive.
#
# 2. **Class**:
#    - Passengers from higher classes generally show a higher survival rate compared to those from lower classes. This could be due to better access to lifeboats and other safety measures for higher-class passengers.
#
# 3. **Fare**:
#    - Higher fares, which correlate with higher classes, tend to show a connection with higher survival rates. This reinforces the observation that socio-economic status played a role in survival chances.
#
# 4. **Age**:
#    - Younger passengers, particularly children (indicated by the title "Master" or negative age values), have higher survival rates. This suggests a preference for saving children regardless of class.
#
# 5. **Family Size**:
#    - Passengers with family sizes of 1 to 3 show varied survival rates, but very large families or those traveling alone have a lower survival rate. Being with family might have offered better chances of survival through mutual assistance and increased likelihood of being noticed for rescue.
#
# 6. **Embarkation Point**:
#    - The embarkation point shows less clear influence on survival, though some variations can be observed. Passengers embarking from Southampton have a wide range of survival outcomes, possibly due to the higher number of passengers from this point.
#
# 7. **Traveling Alone vs. Not Alone**:
#    - Passengers not traveling alone generally have a higher survival rate. This could be due to the support systems available when traveling with companions, aiding in evacuation efforts.
#
# #### Conclusions and Predictive Insights
#
# - **Gender and Age**: Women and children were more likely to survive, likely due to the "women and children first" protocol followed during maritime disasters.
# - **Socio-Economic Status**: Higher-class passengers had better survival odds, possibly due to better access to life-saving resources.
# - **Family Presence**: Those traveling with family had slightly better chances, possibly due to mutual assistance during the crisis.
#
# #### Predictive Modeling:
# Given these observations, a predictive model for survival could assign higher weights to features such as being female, young, traveling in higher class, and not traveling alone. These features could be pivotal in predicting survival with reasonable accuracy based on historical patterns observed in the dataset.
#
# This analysis, while based on a limited dataset, aligns with historical accounts from maritime disasters, suggesting that socio-economic factors, age, gender, and family dynamics play critical roles in survival outcomes. Further analysis with a more extensive dataset could refine these insights and improve predictive accuracy.

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

analysis_string = """Generate the analysis based on instruction\ that
is delimited by triple backticks.\instruction: ```{instruction_analyis}```
"""

instruction_analysis = f"""You are functioning as an AI prediction analyst whose job is to learn patterns from the data provided of who survived an accident and who didnt.
1. You are given detailed analysis of which passenger are likely to survive and which one not  here {text}
2. Using this analysis predict for each of these passengers if they would have survived or not {prompt2}
3. Generate the analysis in this form Index | Survived , Not Survived
"""

analysis_template = ChatPromptTemplate.from_template(analysis_string)

chat = ChatOpenAI(temperature=0.0, model="gpt-4-turbo", openai_api_key='')
user_analysis = analysis_template.format_messages(instruction_analyis=instruction_analysis)
response = chat(user_analysis)
text=response.content
print(text)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\yukte\AppData\Local\Temp\ipykernel_18092\245434860.py:4: SyntaxWarning: invalid escape sequence '\ '
#   analysis_string = """Generate the analysis based on instruction\ that
# Based on the detailed analysis of survival patterns from the provided passenger data, here are the predictions for each passenger's survival status:
#
# ```
# 0: Master | Survived
# 1: Mr. | Not Survived
# 2: Mr. | Not Survived
# 3: Miss | Survived
# 4: Miss | Survived
# 5: Miss | Not Survived
# 6: Miss | Not Survived
# 7: Mr. | Not Survived
# 8: Miss | Not Survived
# 9: Miss | Survived
# 10: Mr. | Not Survived
# 11: Mr. | Not Survived
# 12: Miss | Survived
# 13: Mr. | Not Survived
# 14: Mr. | Not Survived
# 15: Miss | Survived
# 16: Mr. | Not Survived
# 17: Miss | Not Survived
# 18: Mr. | Not Survived
# 19: Mr. | Not Survived
# 20: Mr. | Not Survived
# 21: Mr. | Not Survived
# 22: Miss | Survived
# 23: Mr. | Not Survived
# 24: Mr. | Not Survived
# 25: Master | Survived
# 26: Mr. | Not Survived
# 27: Mr. | Not Survived
# 28: Master | Survived
# 29: Miss | Not Survived
# 30: Mr. | Not Survived
# 31: Miss | Not Survived
# 32: Mr. | Not Survived
# 33: Miss | Not Survived
# 34: Mr. | Not Survived
# 35: Mr. | Not Survived
# 36: Mr. | Not Survived
# 37: Miss | Not Survived
# 38: Miss | Not Survived
# 39: Mr. | Not Survived
# 40: Mr. | Not Survived
# 41: Mr. | Not Survived
# 42: Mr. | Not Survived
# 43: Mr. | Not Survived
# 44: Mrs. | Survived
# 45: Mr. | Not Survived
# 46: Mr. | Not Survived
# 47: Mr. | Not Survived
# 48: Mr. | Not Survived
# 49: Mr. | Not Survived
# 50: Miss | Survived
# 51: Mrs. | Survived
# 52: Mr. | Not Survived
# 53: Master | Survived
# 54: Mr. | Not Survived
# 55: Miss | Survived
# 56: Mr. | Not Survived
# 57: Mrs. | Survived
# 58: Miss | Not Survived
# 59: Miss | Not Survived
# 60: Mr. | Not Survived
# 61: Miss | Survived
# 62: Mrs. | Survived
# 63: Mr. | Not Survived
# 64: Mr. | Not Survived
# 65: Mrs. | Survived
# 66: Mr. | Not Survived
# 67: Mr. | Not Survived
# 68: Mr. | Not Survived
# 69: Mrs. | Survived
# 70: Mrs. | Survived
# 71: Miss | Survived
# 72: Mr. | Not Survived
# 73: Miss | Survived
# 74: Mr. | Not Survived
# 75: Mr. | Not Survived
# 76: Miss | Not Survived
# 77: Miss | Survived
# 78: Miss | Not Survived
# 79: Mrs. | Survived
# 80: Mr. | Not Survived
# 81: Mrs. | Survived
# 82: Mrs. | Survived
# 83: Mr. | Not Survived
# 84: Mr. | Not Survived
# 85: Mr. | Not Survived
# 86: Miss | Survived
# 87: Miss | Not Survived
# 88: Mr. | Not Survived
# 89: Mr. | Not Survived
# 90: Master | Survived
# 91: Miss | Survived
# 92: Mr. | Not Survived
# 93: Mr. | Not Survived
# 94: Mr. | Not Survived
# 95: Mr. | Not Survived
# 96: Mr. | Not Survived
# 97: Mr. | Not Survived
# 98: Mrs. | Survived
# 99: Mr. | Not Survived
# 100: Mr. | Not Survived
# 101: Mr. | Not Survived
# 102: Mrs. | Survived
# 103: Mr. | Not Survived
# 104: Mr. | Not Survived
# 105: Mr. | Not Survived
# 106: Mrs. | Survived
# 107: Mr. | Not Survived
# 108: Mr. | Not Survived
# 109: Mr. | Not Survived
# 110: Mrs. | Survived
# 111: Mr. | Not Survived
# 112: Mrs. | Survived
# 113: Mr. | Not Survived
# 114: Mr. | Not Survived
# 115: Mr. | Not Survived
# 116: Mr. | Not Survived
# 117: Mr. | Not Survived
# 118: Mrs. | Survived
# 119: Mrs. | Survived
# 120: Mr. | Not Survived
# 121: Miss | Not Survived
# 122: Miss | Survived
# 123: Master | Survived
# 124: Mr. | Not Survived
# 125: Mr. | Not Survived
# 126: Miss | Not Survived
# 127: Mr. | Not Survived
# 128: Mrs. | Survived
# 129: Mr. | Not Survived
# 130: Miss | Not Survived
# 131: Master | Survived
# 132: Mr. | Not Survived
# 133: Miss | Not Survived
# 134: Mr. | Not Survived
# 135: Mrs. | Survived
# 136: Miss | Not Survived
# 137: Mr. | Not Survived
# 138: Mr. | Not Survived
# 139: Mrs. | Survived
# 140: Mr. | Not Survived
# 141: Mrs. | Survived
# 142: Mr. | Not Survived
# 143: Mr. | Not Survived
# 144: Mrs. | Survived
# 145: Mrs. | Survived
# 146: Mr. | Not Survived
# 147: Mr. | Not Survived
# 148: Mrs. | Survived
# 149: Mr. | Not Survived
# 150: Mr. | Not Survived
# 151: Mr. | Not Survived
# 152: Mr. | Not Survived
# 153: Miss | Survived
# 154: Mr. | Not Survived
# 155: Mr. | Not Survived
# 156: Mr. | Not Survived
# 157: Miss | Not Survived
# 158: Mrs. | Survived
# 159: Mrs. | Survived
# 160: Mr. | Not Survived
# 161: Mr. | Not Survived
# 162: Mr. | Not Survived
# 163: Mrs. | Survived
# 164: Mr. | Not Survived
# 165: Mr. | Not Survived
# 166: Mr. | Not Survived
# 167: Mrs. | Survived
# 168: Mr. | Not Survived
# 169: Mr. | Not Survived
# 170: Mr. | Not Survived
# 171: Miss | Survived
# 172: Mr. | Not Survived
# 173: Miss | Survived
# 174: Mr. | Not Survived
# 175: Mr. | Not Survived
# 176: Mrs. | Survived
# 177: Miss | Not Survived
# 178: Miss | Survived
# 179: Mr. | Not Survived
# 180: Mr. | Not Survived
# 181: Mr. | Not Survived
# 182: Mr. | Not Survived
# 183: Miss | Survived
# 184: Mr. | Not Survived
# 185: Mr. | Not Survived
# 186: Mr. | Not Survived
# 187: Mr. | Not Survived
# 188: Mr. | Not Survived
# 189: Mrs. | Survived
# 190: Mr. | Not Survived
# 191: Mr. | Not Survived
# 192: Mr. | Not Survived
# 193: Mr. | Not Survived
# 194: Mrs. | Survived
# 195: Mrs. | Survived
# 196: Miss | Not Survived
# 197: Mr. | Not Survived
# 198: Mrs. | Survived
# 199: Miss | Survived
# 200: Mr. | Not Survived
# 201: Miss | Not Survived
# 202: Miss | Survived
# 203: Mrs. | Survived
# 204: Mr. | Not Survived
# 205: Mrs. | Survived
# 206: Mr. | Not Survived
# 207: Mr. | Not Survived
# 208: Mr. | Not Survived
# 209: Mr. | Not Survived
# 210: Mr. | Not Survived
# 211: Mr. | Not Survived
# 212: Miss | Survived
# 213: Mr. | Not Survived
# 214: Miss | Survived
# 215: Master | Survived
# 216: Miss | Survived
# 217: Mr. | Not Survived
# 218: Mrs. | Survived
# 219: Mr. | Not Survived
# 220: Mr. | Not Survived
# 221: Miss | Not Survived
# 222: Mr. | Not Survived
# 223: Mr. | Not Survived
# 224: Mr. | Not Survived
# 225: Mrs. | Survived
# 226: Mr. | Not Survived
# 227: Master | Survived
# 228: Mrs. | Survived
# 229: Miss | Not Survived
# 230: Mr. | Not Survived
# 231: Miss | Survived
# 232: Mr. | Not Survived
# 233: Mrs. | Survived
# 234: Mr. | Not Survived
# 235: Miss | Not Survived
# 236: Mrs. | Survived
# 237: Miss | Not Survived
# 238: Miss | Not Survived
# 239: Mr. | Not Survived
# 240: Mr. | Not Survived
# 241: Mrs. | Survived
# 242: Mr. | Not Survived
# 243: Miss | Not Survived
# 244: Mr. | Not Survived
# 245: Mr. | Not Survived
# 246: Mr. | Not Survived
# 247: Mr. | Not Survived
# 248: Mr. | Not Survived
# 249: Mr. | Not Survived
# 250: Miss | Not Survived
# 251: Mr. | Not Survived
# 252: Mr. | Not Survived
# 253: Mr. | Not Survived
# 254: Mr. | Not Survived
# 255: Mr. | Not Survived
# 256: Mr. | Not Survived
# 257: Mrs. | Survived
# 258: Mr. | Not Survived
# 259: Mrs. | Survived
# 260: Miss | Not Survived
# 261: Mr. | Not Survived
# 262: Miss | Not Survived
# 263: Mr. | Not Survived
# 264: Mr. | Not Survived
# 265: Mr. | Not Survived
# 266: Mr. | Not Survived
# 267: Mr. | Not Survived
# ```

# %% [markdown]
# Thought Refinement Exercise

# %%
#Creating a smaller prompt to refine the analysis 
# Create dictionaries for training and test sentences
train_dict2 = {i: sentence for i, sentence in enumerate(train_sentences.head(200))}

prompt_small = "\n\n"
for key, sentence in train_dict2.items():
    prompt_small += f"{key}: {sentence}\n\n"

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

analysis_string = """Generate the analysis based on instruction\ that
is delimited by triple backticks.\instruction: ```{instruction_analyis}```
"""

instruction_analysis = f"""You are functioning as an AI prediction analyst whose job is to learn patterns from the data provided of who survived an accident and who didnt.
1. In the initial analysis you have taken some data and analyzed patterns in data which can help us predict wether a passenger will survive an accident or not 
2. The analysis is placed here in the {text}
3. However there is alot of scope for improvement to this analysis as we are not to predict 100% of survival cases
4. Can you please relook at the analysis and here {prompt_small} some more data to build a better analysis this time
"""

analysis_template = ChatPromptTemplate.from_template(analysis_string)

chat = ChatOpenAI(temperature=0.0, model="gpt-4-turbo", openai_api_key='')
user_analysis = analysis_template.format_messages(instruction_analyis=instruction_analysis)
response = chat(user_analysis)
text2=response.content
print(text2)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\yukte\AppData\Local\Temp\ipykernel_18092\1725034076.py:4: SyntaxWarning: invalid escape sequence '\ '
#   analysis_string = """Generate the analysis based on instruction\ that
# ### Analysis of Survival Patterns Based on Passenger Data
#
# #### Overview
# The expanded dataset includes detailed attributes of passengers such as age, class, fare, embarkation point, family size, whether they were alone, title, and survival status. This comprehensive data allows for a deeper analysis to identify more nuanced patterns that may influence the likelihood of survival in an accident.
#
# #### Key Observations and Patterns
#
# 1. **Gender and Title**:
#    - Consistently, titles such as "Mrs.", "Miss", and "Master" correlate with higher survival rates, reinforcing the trend that women and children had a higher likelihood of survival.
#    - "Mr." title, typically representing adult males, consistently shows lower survival rates across various classes and family sizes.
#
# 2. **Class**:
#    - Higher class passengers continue to exhibit a higher survival rate. This trend is persistent even when controlling for other factors like fare and embarkation points, suggesting a strong class bias in survival chances.
#
# 3. **Fare**:
#    - There is a positive correlation between fare and survival, indicating that passengers who paid more (likely correlated with higher class) had better survival odds. This could be due to better placement on the ship or closer access to lifeboats.
#
# 4. **Age**:
#    - Younger passengers, especially those with titles like "Master" or "Miss," show higher survival rates. Negative age values, likely representing infants or very young children, also have higher survival rates, suggesting a protective effect for the youngest passengers.
#
# 5. **Family Size**:
#    - Medium-sized family groups (2-4 members) show better survival rates compared to those traveling alone or with very large families. This might be due to better ability to navigate the crisis with moderate family support without the hindrance of a large group.
#
# 6. **Embarkation Point**:
#    - Variations in survival rates by embarkation points are observed, with passengers from Queenstown showing slightly higher survival rates in some cases. This could be influenced by the composition of passengers embarking from these locations.
#
# 7. **Traveling Alone vs. Not Alone**:
#    - Passengers not traveling alone generally show higher survival rates, supporting the idea that companions could aid in survival efforts. However, very large groups do not necessarily have improved survival, possibly due to difficulties in coordinating during the crisis.
#
# #### Conclusions and Predictive Insights
#
# - **Gender, Age, and Title**: Strong indicators of survival include being female, young, or holding titles like "Miss," "Mrs.," or "Master."
# - **Socio-Economic Status**: Higher-class passengers and those paying higher fares had better survival odds, likely due to better access to life-saving resources.
# - **Family Dynamics**: Traveling with a family size of 2 to 4 increases survival chances, likely due to optimal support without the drawbacks of large group coordination.
#
# #### Predictive Modeling:
# For future predictive models, it would be beneficial to consider these factors with significant weights:
# - Gender (female)
# - Age (younger passengers)
# - Socio-economic status (higher class and fare)
# - Family size (optimal size of 2-4)
# - Traveling companions (not traveling alone)
#
# This refined analysis, with a broader dataset, confirms and extends previous insights into the factors influencing survival during maritime disasters. Further data collection and advanced modeling techniques like machine learning could enhance the predictive accuracy and provide more personalized survival predictions.

# %%
#Reducing the analysis size 

text_short = """"#### Key Observations and Patterns

1. **Gender and Title**:
   - Consistently, titles such as "Mrs.", "Miss", and "Master" correlate with higher survival rates, reinforcing the trend that women and children had a higher likelihood of survival.
   - "Mr." title, typically representing adult males, consistently shows lower survival rates across various classes and family sizes.

2. **Class**:
   - Higher class passengers continue to exhibit a higher survival rate. This trend is persistent even when controlling for other factors like fare and embarkation points, suggesting a strong class bias in survival chances.

3. **Fare**:
   - There is a positive correlation between fare and survival, indicating that passengers who paid more (likely correlated with higher class) had better survival odds. This could be due to better placement on the ship or closer access to lifeboats.

4. **Age**:
   - Younger passengers, especially those with titles like "Master" or "Miss," show higher survival rates. Negative age values, likely representing infants or very young children, also have higher survival rates, suggesting a protective effect for the youngest passengers.

5. **Family Size**:
   - Medium-sized family groups (2-4 members) show better survival rates compared to those traveling alone or with very large families. This might be due to better ability to navigate the crisis with moderate family support without the hindrance of a large group.

6. **Embarkation Point**:
   - Variations in survival rates by embarkation points are observed, with passengers from Queenstown showing slightly higher survival rates in some cases. This could be influenced by the composition of passengers embarking from these locations.

7. **Traveling Alone vs. Not Alone**:
   - Passengers not traveling alone generally show higher survival rates, supporting the idea that companions could aid in survival efforts. However, very large groups do not necessarily have improved survival, possibly due to difficulties in coordinating during the crisis.

#### Conclusions and Predictive Insights

- **Gender, Age, and Title**: Strong indicators of survival include being female, young, or holding titles like "Miss," "Mrs.," or "Master."
- **Socio-Economic Status**: Higher-class passengers and those paying higher fares had better survival odds, likely due to better access to life-saving resources.
- **Family Dynamics**: Traveling with a family size of 2 to 4 increases survival chances, likely due to optimal support without the drawbacks of large group coordination."""

# %% [markdown]
# Predicting with new analysis

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

analysis_string = """Generate the analysis based on instruction\ that
is delimited by triple backticks.\instruction: ```{instruction_analyis}```
"""

instruction_analysis = f"""You are functioning as an AI prediction analyst whose job is to learn patterns from the data provided of who survived an accident and who didnt.
1. You are given detailed analysis of which passenger are likely to survive and which one not  here {text_short}
2. Using this analysis predict for each of these passengers if they would have survived or not {prompt2}
3. Generate the analysis in this form Index | Survived , Not Survived
"""

analysis_template = ChatPromptTemplate.from_template(analysis_string)

chat = ChatOpenAI(temperature=0.0, model="gpt-4-turbo", openai_api_key='')
user_analysis = analysis_template.format_messages(instruction_analyis=instruction_analysis)
response = chat(user_analysis)
text3=response.content
print(text3)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\yukte\AppData\Local\Temp\ipykernel_13120\3203265956.py:4: SyntaxWarning: invalid escape sequence '\ '
#   analysis_string = """Generate the analysis based on instruction\ that
# c:\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# c:\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Based on the detailed analysis provided and the patterns observed in the survival rates of passengers, here are the predictions for each passenger listed:
#
# ```
# Index | Survival Prediction
# ---------------------------
# 0     | Survived
# 1     | Not Survived
# 2     | Not Survived
# 3     | Survived
# 4     | Survived
# 5     | Survived
# 6     | Survived
# 7     | Not Survived
# 8     | Survived
# 9     | Survived
# 10    | Not Survived
# 11    | Not Survived
# 12    | Survived
# 13    | Not Survived
# 14    | Not Survived
# 15    | Survived
# 16    | Not Survived
# 17    | Survived
# 18    | Not Survived
# 19    | Not Survived
# 20    | Not Survived
# 21    | Not Survived
# 22    | Survived
# 23    | Not Survived
# 24    | Not Survived
# 25    | Survived
# 26    | Not Survived
# 27    | Not Survived
# 28    | Survived
# 29    | Survived
# 30    | Not Survived
# 31    | Survived
# 32    | Not Survived
# 33    | Survived
# 34    | Not Survived
# 35    | Not Survived
# 36    | Not Survived
# 37    | Survived
# 38    | Survived
# 39    | Not Survived
# 40    | Not Survived
# 41    | Not Survived
# 42    | Not Survived
# 43    | Not Survived
# 44    | Survived
# 45    | Not Survived
# 46    | Not Survived
# 47    | Not Survived
# 48    | Not Survived
# 49    | Not Survived
# 50    | Survived
# 51    | Survived
# 52    | Not Survived
# 53    | Survived
# 54    | Not Survived
# 55    | Survived
# 56    | Not Survived
# 57    | Survived
# 58    | Survived
# 59    | Survived
# 60    | Not Survived
# 61    | Survived
# 62    | Survived
# 63    | Not Survived
# 64    | Not Survived
# 65    | Survived
# 66    | Not Survived
# 67    | Not Survived
# 68    | Not Survived
# 69    | Survived
# 70    | Survived
# 71    | Survived
# 72    | Not Survived
# 73    | Survived
# 74    | Not Survived
# 75    | Not Survived
# 76    | Survived
# 77    | Survived
# 78    | Survived
# 79    | Survived
# 80    | Not Survived
# 81    | Survived
# 82    | Survived
# 83    | Not Survived
# 84    | Not Survived
# 85    | Not Survived
# 86    | Survived
# 87    | Survived
# 88    | Not Survived
# 89    | Not Survived
# 90    | Survived
# 91    | Survived
# 92    | Not Survived
# 93    | Not Survived
# 94    | Not Survived
# 95    | Not Survived
# 96    | Not Survived
# 97    | Not Survived
# 98    | Survived
# 99    | Not Survived
# 100   | Not Survived
# 101   | Not Survived
# 102   | Survived
# 103   | Not Survived
# 104   | Not Survived
# 105   | Not Survived
# 106   | Survived
# 107   | Not Survived
# 108   | Not Survived
# 109   | Not Survived
# 110   | Survived
# 111   | Not Survived
# 112   | Survived
# 113   | Not Survived
# 114   | Not Survived
# 115   | Not Survived
# 116   | Not Survived
# 117   | Not Survived
# 118   | Survived
# 119   | Survived
# 120   | Not Survived
# 121   | Survived
# 122   | Survived
# 123   | Survived
# 124   | Not Survived
# 125   | Not Survived
# 126   | Not Survived
# 127   | Not Survived
# 128   | Survived
# 129   | Not Survived
# 130   | Survived
# 131   | Survived
# 132   | Not Survived
# 133   | Survived
# 134   | Not Survived
# 135   | Survived
# 136   | Survived
# 137   | Not Survived
# 138   | Not Survived
# 139   | Survived
# 140   | Not Survived
# 141   | Survived
# 142   | Not Survived
# 143   | Not Survived
# 144   | Survived
# 145   | Survived
# 146   | Not Survived
# 147   | Not Survived
# 148   | Survived
# 149   | Not Survived
# 150   | Not Survived
# 151   | Not Survived
# 152   | Not Survived
# 153   | Survived
# 154   | Not Survived
# 155   | Not Survived
# 156   | Not Survived
# 157   | Survived
# 158   | Survived
# 159   | Survived
# 160   | Not Survived
# 161   | Not Survived
# 162   | Not Survived
# 163   | Survived
# 164   | Not Survived
# 165   | Not Survived
# 166   | Not Survived
# 167   | Survived
# 168   | Not Survived
# 169   | Not Survived
# 170   | Not Survived
# 171   | Survived
# 172   | Not Survived
# 173   | Survived
# 174   | Not Survived
# 175   | Not Survived
# 176   | Survived
# 177   | Survived
# 178   | Survived
# 179   | Not Survived
# 180   | Not Survived
# 181   | Not Survived
# 182   | Not Survived
# 183   | Survived
# 184   | Not Survived
# 185   | Not Survived
# 186   | Not Survived
# 187   | Not Survived
# 188   | Not Survived
# 189   | Survived
# 190   | Not Survived
# 191   | Not Survived
# 192   | Not Survived
# 193   | Not Survived
# 194   | Survived
# 195   | Survived
# 196   | Survived
# 197   | Not Survived
# 198   | Survived
# 199   | Survived
# 200   | Not Survived
# 201   | Survived
# 202   | Survived
# 203   | Survived
# 204   | Not Survived
# 205   | Survived
# 206   | Not Survived
# 207   | Not Survived
# 208   | Not Survived
# 209   | Not Survived
# 210   | Not Survived
# 211   | Not Survived
# 212   | Survived
# 213   | Not Survived
# 214   | Survived
# 215   | Survived
# 216   | Survived
# 217   | Not Survived
# 218   | Survived
# 219   | Not Survived
# 220   | Not Survived
# 221   | Survived
# 222   | Not Survived
# 223   | Not Survived
# 224   | Not Survived
# 225   | Survived
# 226   | Not Survived
# 227   | Survived
# 228   | Survived
# 229   | Survived
# 230   | Not Survived
# 231   | Survived
# 232   | Not Survived
# 233   | Survived
# 234   | Not Survived
# 235   | Survived
# 236   | Survived
# 237   | Survived
# 238   | Survived
# 239   | Not Survived
# 240   | Not Survived
# 241   | Survived
# 242   | Not Survived
# 243   | Survived
# 244   | Not Survived
# 245   | Not Survived
# 246   | Not Survived
# 247   | Not Survived
# 248   | Not Survived
# 249   | Not Survived
# 250   | Survived
# 251   | Not Survived
# 252   | Not Survived
# 253   | Not Survived
# 254   | Not Survived
# 255   | Not Survived
# 256   | Not Survived
# 257   | Survived
# 258   | Not Survived
# 259   | Survived
# 260   | Survived
# 261   | Not Survived
# 262   | Survived
# 263   | Not Survived
# 264   | Not Survived
# 265   | Not Survived
# 266   | Not Survived
# 267   | Not Survived
# ```
#
# This prediction is based on the observed patterns of survival related to gender, age, class, fare, family size, and other factors as detailed in the provided analysis.
